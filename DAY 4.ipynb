# %%
# importing necessary libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the daset
df = pd.read_csv('Student_Behaviour.csv')
# load top 5 rows
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
# information of the dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    str
#  1   Gender                                                  235 non-null    str
#  2   Department                                              235 non-null    str
#  3   Height(CM)                                              235 non-null    float64
#  4   Weight(KG)                                              235 non-null    float64
#  5   10th Mark                                               235 non-null    float64
#  6   12th Mark                                               235 non-null    float64
#  7   college mark                                            235 non-null    float64
# ...

# %%
# stat of the dataset
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.842128   68.780128     70.660553
# std     21.510805   14.895844   13.050800   11.016533     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
df['Certification Course']
# Out:
# 0       No
# 1       No
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 230    Yes
# 231    Yes
# 232    Yes
# 233    Yes
# 234     No
# Name: Certification Course, Length: 235, dtype: str

# %%
# integer loc-rows as well as cols
df.iloc[4:9,1:3]
# Out:
#    Gender Department
# 4    Male        BCA
# 5  Female        BCA
# 6    Male        BCA
# 7    Male        BCA
# 8    Male        BCA

# %%
df.columns
# Out:
# Index(['Certification Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='str')

# %%
# unique values in each col?
#gender 
df['Gender'].unique()
# Out:
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
# a simple visualization of the gender col
df['Gender'].value_counts().plot(kind='bar')
plt.title('Bar plot on gender')
plt.show()

# %%
df['Department'].value_counts().plot(kind='pie',autopct='%1.2%%')
plt.title('Pie chart based on department')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df['Department'].value_counts().plot(kind='pie',autopct='%1.2%%')
#       2 plt.title('Pie chart based on department')
#       3 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
# ...

# %%
# Univariate analysis - uni means single - variate - variable 
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=df, x='Travelling Time', bins=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 sns.histplot(data=df, x='Travelling Time', bins=30)
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)   1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1382     )
# ...

# %%
# bi variate analysis:2 variables
sns.barplot(data=df, x='10th Mark', y='12th Mark')
plt.title('Bi variate analysis using Bar plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # bi variate analysis:2 variables
#       2 sns.barplot(data=df, x='10th Mark', y='12th Mark')
# ----> 3 plt.title('Bi variate analysis using Bar plot')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.scatterplot(data=df, x='Height(CM)',y='Weight(KG)')
plt.title('Scatter PLot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 sns.scatterplot(data=df, x='Height(CM)',y='Weight(KG)')
# ----> 2 plt.title('Scatter PLot')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.countplot(data=df, x='Stress Level ', hue='Department')
plt.title("Countplot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 sns.countplot(data=df, x='Stress Level ', hue='Department')
# ----> 2 plt.title("Countplot")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# multi variate - heatmap - corr
num_cols  = df.select_dtypes(include='number')
num_cols
# Out:
#      Height(CM)  Weight(KG)  10th Mark  12th Mark  college mark  \
# 0         100.0        58.0       79.0       65.0          80.0
# 1          90.0        40.0       70.0       80.0          70.0
# 2         159.0        78.0       69.5       61.0          55.0
# 3         147.0        20.0       70.0       59.0          58.0
# 4         170.0        54.0       40.0       65.0          30.0
# ..          ...         ...        ...        ...           ...
# 230       170.0        76.0       72.0       67.0          65.0
# 231       172.0        52.0       72.0       70.0          76.0
# 232       139.0        33.0       90.0       75.0          70.0
# 233       153.0        58.0       85.0       74.0          75.0
# 234       155.0        39.0       45.0       45.0          50.0
#
#      salary expectation
# 0                 40000
# 1                 15000
# 2                 13000
# 3               1500000
# 4                 50000
# ..                  ...
# ...

# %%
cm = num_cols.corr()
cm
# Out:
#                     Height(CM)  Weight(KG)  10th Mark  12th Mark  \
# Height(CM)            1.000000    0.275948   0.019896  -0.120672
# Weight(KG)            0.275948    1.000000   0.062394  -0.019208
# 10th Mark             0.019896    0.062394   1.000000   0.473618
# 12th Mark            -0.120672   -0.019208   0.473618   1.000000
# college mark         -0.018535   -0.014901   0.466234   0.425123
# salary expectation   -0.010708   -0.087787  -0.055694  -0.085610
#
#                     college mark  salary expectation
# Height(CM)             -0.018535           -0.010708
# Weight(KG)             -0.014901           -0.087787
# 10th Mark               0.466234           -0.055694
# 12th Mark               0.425123           -0.085610
# college mark            1.000000           -0.103034
# salary expectation     -0.103034            1.000000

# %%
sns.heatmap(cm)
# Out:
# <Axes: >

# %%
sns.heatmap(cm, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# pairplot
sns.pairplot(data=df)

# %%
# filtering 
df[['Department', 'Gender']].value_counts()
# Out:
# Department                     Gender
# BCA                            Male      94
#                                Female    38
# Commerce                       Male      31
#                                Female    29
# B.com ISM                      Male      22
# B.com Accounting and Finance   Male       9
#                                Female     6
# B.com ISM                      Female     6
# Name: count, dtype: int64

# %%
df[df['Department']=='BCA'].shape[0]
# Out:
# 132

# %%
df[(df['Department']=='BCA') & (df['Gender'] == 'Female')].shape[0]
# Out:
# 38

# %%
df[(df['Department']=='Commerce') & (df['Gender'] == 'Male')].shape[0]
# Out:
# 31

# %%
df[(df['Department']=='B.com ISM') & (df['Gender'] == 'Male')].shape[0]
# Out:
# 22

# %%
df[df['Stress Level ']=='Bad'].shape[0]
# Out:
# 68

# %%
df['Stress Level '].unique()
# Out:
# <ArrowStringArray>
# ['Bad', 'Awful', 'Good', 'fabulous']
# Length: 4, dtype: str

# %%
df[(df['Department']=='B.com ISM')&(df['Stress Level ']=='fabulous')].shape[0]
# Out:
# 2

# %%
df['prefer to study in'].unique()
# Out:
# <ArrowStringArray>
# ['Morning', 'Anytime', 'Night']
# Length: 3, dtype: str

# %%
df['prefer to study in'].value_counts().plot(kind='bar')
plt.title('Bar plot on  Study time')
plt.show()

# %%
sns.countplot(data=df,x='prefer to study in', hue='college mark')
plt.title('Countplot')
plt.show()

# %%
df['salary expectation'].unique()
# Out:
# array([  40000,   15000,   13000, 1500000,   50000,   20000,   25000,
#          18000,      17,   60000,       0,   30000,   10000,   17000,
#         100000,    8000,   12000,      21,   35000,   16000,    5000,
#          12500,   11000,  120000,   45000,   23000,  500000,  700000,
#             10,      15,      22,     100,     500,    7000])

# %%
df['salary expectation'].min()
# Out:
# np.int64(0)

# %%
df['salary expectation'].max()
# Out:
# np.int64(1500000)

# %%
df['salary expectation'].mean()
# Out:
# np.float64(32481.68085106383)

# %% [markdown]
# ,

# %%
<h1>Machine Learning - Supervised<h1>
# Out:
#   Cell In[3], line 1
#     <h1>Machine Learning - Supervised<h1>
#     ^
# SyntaxError: invalid syntax

# %%
# import necessary libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# load the dataset
hr = pd.read_csv(r'C:\Users\admin\Downloads\Lab 21 House_Rent_Dataset.csv')
hr.head(3)
# Out:
#     Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2  Super Area
# 1  2022-05-13    2  20000   800       1 out of 3  Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner

# %% [markdown]
# <h1>Machine Learning - Supervised</h1>

# %%
hr.shape
# Out:
# (4746, 12)

# %%
hr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   str
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   str
#  5   Area Type          4746 non-null   str
#  6   Area Locality      4746 non-null   str
#  7   City               4746 non-null   str
#  8   Furnishing Status  4746 non-null   str
#  9   Tenant Preferred   4746 non-null   str
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   str
# dtypes: int64(4), str(8)
# memory usage: 887.8 KB

# %%
hr.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
hr.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='str')

# %%
hr['Furnishing Status'].unique()
# Out:
# <ArrowStringArray>
# ['Unfurnished', 'Semi-Furnished', 'Furnished']
# Length: 3, dtype: str

# %%
hr['Tenant Preferred'].unique()
# Out:
# <ArrowStringArray>
# ['Bachelors/Family', 'Bachelors', 'Family']
# Length: 3, dtype: str

# %%
plt.figure(figsize=(14, 15))

for i,col in enumerate(["Area Type",
    "City",
    "Furnishing Status",
    "Tenant Preferred",
    "Point of Contact"]):

  plt.subplot(4, 2, i + 1)  
  sns.countplot(data=hr, x=col)
